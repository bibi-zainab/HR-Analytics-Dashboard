# %% [markdown]
# # HR Analytics EDA Notebook
#
# This notebook walks through the data cleaning and exploratory analysis workflow for the HR analytics dashboard.

# %%
import pandas as pd
import sys
from pathlib import Path
sys.path.append('../src')
from data_cleaning import load_raw_data, clean_employee_data
from eda import create_visuals

raw_path = '../data/raw/employee_attrition.csv'
df = load_raw_data(raw_path)
cleaned = clean_employee_data(df)
cleaned.head()

# %%
create_visuals(cleaned, '../images')
cleaned.describe(include='number').T
